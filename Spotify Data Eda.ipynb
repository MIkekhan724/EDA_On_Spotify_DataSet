# %% [markdown]
# #                             Spotify Data Analysis using Python - Project

# %% [markdown]
# ## INTRODUCTION
#
# Spotify is a Swedish audio streaming and media services provider founded in April 2006. It is the world's largest music streaming service provider and has over 381 million monthly active users, which also includes 172 million paid subscribers.
#
# Here, We'll exploring and quantify data about music and drawing valuable insights.
#
# Perform an exploratory data analysis (EDA) and data visualization project using data from Spotify using Python.
#
# Data analysis exploring the relationship between the audio features of a song and how positive or negative its lyrics are, involving sentiment analysis.
#
# Includes data collection script that scrapes audio feature data from the Spotify API, as well as lyrical data from the LyricWikiAPI
#
# Spotify Data Analysis makes use of secondary data from Spotify. Learners will use data to identify patterns and relationships between different characteristics. The activity will support learners in developing their ability to review and interpret a dataset. The activity starts by encouraging learners to think of questions that the dataset might answer and thus develop their “Problem” skills. Once the dataset has been analysed learners will have the opportunity to reorganise and restructure data to help them answer their questions

# %% [markdown]
# ### Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Data set

# %%
df_track=pd.read_csv('tracks.csv')

# %%
# Head Of Records
df_track.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %% [markdown]
# ## Spotify Tracks Dataset Analysis

# %%
# checking Null Values In the Dataset
df_track.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %% [markdown]
# Here You can see the only name columns have the missing values

# %%
# Let's see Percentage of null values in the dataset
df_track.isnull().mean().round(4)*100
# Out:
# id                  0.00
# name                0.01
# popularity          0.00
# duration_ms         0.00
# explicit            0.00
# artists             0.00
# id_artists          0.00
# release_date        0.00
# danceability        0.00
# energy              0.00
# key                 0.00
# loudness            0.00
# mode                0.00
# speechiness         0.00
# acousticness        0.00
# instrumentalness    0.00
# liveness            0.00
# valence             0.00
# tempo               0.00
# time_signature      0.00
# dtype: float64

# %% [markdown]
# Here You can Clearly see that name column have around 0.01% missing Values

# %%
#checking Info of Dataset
df_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %% [markdown]
# ## Descriptive statistics of Spotify tracks

# %%
#df_track.describe().T
df_track.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %% [markdown]
# ### Top 10 most popular songs on Spotify

# %%
df_sorted=df_track.sort_values(by='popularity', ascending=True).head(10)
df_sorted
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %% [markdown]
# ### Top 10 songs poularity Greater than 90

# %%
most_popular=df_track[df_track['popularity'] >=90].sort_values(by='popularity',ascending=False).head(10)
most_popular
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 93805  7MAibcTli4IisCtbHKrGMh
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 93807  4cG7HUWYHBV6R6tHn1gxrl
#
#                                                     name  popularity  \
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# 92810                                    Save Your Tears          97
# 92811                                          telepatía          97
# 93805                                Leave The Door Open          96
# 92813                                    Blinding Lights          96
# 92814                                       The Business          95
# ...

# %% [markdown]
# ### Alternate Method For Above Code

# %%
most_popular2=df_track[df_track['popularity'] >=90].nlargest(10,'popularity')
most_popular2
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %% [markdown]
# ### Second AlterNate method

# %%
most_popular3=df_track.query('popularity >90',inplace=False).sort_values('popularity',ascending=False)[:10]
most_popular3
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %% [markdown]
# ### Top 10 least popular songs on Spotify

# %%
least = df_track.sort_values('popularity', ascending = True).head(10)
least
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %% [markdown]
# ### Changing index to release date

# %%
df_track.set_index('release_date',inplace=True)

# %% [markdown]
# ### convert release_date to date time

# %%
df_track.index=pd.to_datetime(df_track.index)
df_track.head(10)
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# 1922-01-01    0BRXJHRNGQ3W4v9frnSfhu                            Ave Maria
# 1922-01-01    0Dd9ImXtAtGwsmsAD69KZT                       La Butte Rouge
# 1922-01-01    0IA0Hju8CAgYfV1hwhidBH                              La Java
# 1922-01-01    0IgI1UCz84pYeVetnl1lGP                   Old Fashioned Girl
# 1922-03-29    0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# ...

# %%
df_track.index.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Check artist at 18th row of Spotify Tracks Dataset

# %%
df_track[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922-01-01 00:00:00, dtype: object

# %% [markdown]
# ### Converting duration from millisecond to second on Spotify Tracks Dataset

# %%
df_track['duration']=df_track['duration_ms'].apply(lambda x: round(x/1000))
df_track.drop('duration_ms',inplace=True,axis=1)
df_track.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %%
df_track.columns
# Out:
# Index(['id', 'name', 'popularity', 'explicit', 'artists', 'id_artists',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration'],
#       dtype='object')

# %% [markdown]
# ### Correlation Heatmap between Variable using Pearson correlation method

# %%
corr_df=df_track.drop(['key','mode','explicit'],axis=1).corr(method='pearson')
#sns.set(rc={'figure.figsize':(20,7)})
plt.figure(figsize=(14,6))
heat_map=sns.heatmap(corr_df,annot=True,fmt='.1g',vmin=-1,vmax=1,center=0,cmap='inferno',linewidths=1,linecolor='Black')
heat_map.set_title("Correlation Heatmap Between Variables")
heat_map.set_xticklabels(heat_map.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ### Considering 0.4% of the total dataset to create Regression plots

# %%
sample_df=df_track.sample(int(0.004*len(df_track)))
print(len(sample_df))
# Out:
# 2346

# %% [markdown]
# ### Regression plot - Correlation between Loudness and Energy

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,x='energy',y='loudness',color='c').set(title='Loudness vs Energy Correlation')
plt.show()

# %% [markdown]
#  It's shows that there is high correlation it's mean if loudness increase the energy alse increases vice versa

# %% [markdown]
# ### Regression plot - Correlation between Popularity and Acousticness

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,x='popularity',y='acousticness',color='b').set(title='popularity vs acousticness Correlation')
plt.show()

# %% [markdown]
# It's shows there is negative correlation between popularity and acousticness
#
# it mean if  acousticness increses then popularity decreases

# %% [markdown]
# ### Creating new column in tracks dataset (Year, Release Date)

# %%
df_track['dates']=df_track.index.get_level_values('release_date')
df_track.dates=pd.to_datetime(df_track.dates)
years=df_track.dates.dt.year

# %%
df_track.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %% [markdown]
# ### Distibution plot - Visualize total number of songs on Spotify since 1992

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.distplot(years, color='b').set(title="Numbers of Songs per Year")
plt.show()

# %% [markdown]
# ### number of songs per year using Histogram

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.histplot(data=years, bins='auto',  color='g',  legend=True)
plt.show()

# %%
df_track.columns
# Out:
# Index(['id', 'name', 'popularity', 'explicit', 'artists', 'id_artists',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration', 'dates'],
#       dtype='object')

# %% [markdown]
# ### Duration of Songs Over The Years

# %%
total_duration=df_track['duration']
fig_dims=(20,7)
fig,ax=plt.subplots(figsize = fig_dims)
fig=sns.barplot(x=years,y=total_duration,ax=ax,errwidth=False).set(title='Year Vs Durations')
plt.xticks(rotation=90)
plt.show()

# %%
total_duration=df_track['duration']
sns.set_style(style="whitegrid")
fig_dims=(20,7)
fig,ax=plt.subplots(figsize = fig_dims)
fig=sns.lineplot(x=years,y=total_duration,ax=ax).set(title='Year Vs Durations')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Spotify Features Dataset Analysis

# %% [markdown]
# ### Importing Our Second DataSet

# %%
df_genre=pd.read_csv('SpotifyFeatures.csv')
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %% [markdown]
# ### Duration of songs in different Genres

# %%
sns.set(rc={'figure.figsize':(20,10)})
plt.title('Duration Of the Songs in different Genre')
sns.color_palette('rocket',as_cmap=True)
sns.barplot(y='genre',x='duration_ms',data=df_genre)
plt.xlabel('Duration in Millisecond')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ### Top 5 Genres by Popularity

# %%
sns.set_style(style='darkgrid')
sns.set(rc={'figure.figsize':(20,10)})
famous=df_genre.sort_values("popularity",ascending=False).head(10)
sns.barplot(y='genre',x='popularity',data=famous).set(title='Top 5 Genre by Popularity')
plt.show()
